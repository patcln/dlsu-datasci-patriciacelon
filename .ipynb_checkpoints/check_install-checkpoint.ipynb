# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd
from shapely.geometry import Point

import csv
import os 
import requests
import datetime as dt
import time

from bs4 import BeautifulSoup
from pathlib import Path

import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, silhouette_score, silhouette_samples
from sklearn.cluster import KMeans
from sklearn import preprocessing
from scipy.spatial.distance import cdist, pdist

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Testing GeoPandas installation
# The following cells will test if `geopandas` was installed successfully.

# %%
ph = gpd.read_file('philippines.geojson')
ph.head(2)
# Out:
#                                      source_url            what3words  \
# 0  http://www.openstreetmap.org/node/2694351354    chat.pints.mankind
# 1  http://www.openstreetmap.org/node/2141277725  shadow.vipers.modest
#
#                     upstream                          name completeness  \
# 0  openstreetmap¶n2694351354  20-1 Barangay Health Station       35.29%
# 1  openstreetmap¶n2141277725          24hr Birthing Center       35.29%
#
#                                uuid        date_modified         source  \
# 0  e32de8829d524d60b40a55a2029b765f  2015-11-17T09:43:57  OpenStreetMap
# 1  116f9d20caa946ea969796092d79b0dc  2015-11-17T09:43:57  OpenStreetMap
#
#    version    type physical-address phone email   url defining-hours  \
# 0        2  clinic             None  None  None  None           None
# 1        2  clinic             None  None  None  None           None
#
#                      geometry
# 0  POINT (121.13735 14.56600)
# 1  POINT (123.94312 10.33793)

# %%
fig = plt.figure(figsize=(6,15))
ax = fig.add_subplot(111)

ph.plot(ax=ax, alpha=0.5, column='type', legend=True)
ax.axis('off')
ax.set_title('Health Centers in the Philippines (from OSM)', fontsize=15);
